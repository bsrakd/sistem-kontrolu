# %%
from control import *
import matplotlib.pyplot as plt

fig=plt.figure()
x1=fig.add_subplot(2,2,1)
plt.title("1.")
g = tf(1,[1,1,1])
a,b = step_response(g)
plt.plot(a,b,"r")
plt.grid()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x2=fig.add_subplot(2,2,2)
plt.title("2.")
g = tf(1,[3,1,1])
k,l = step_response(g)
plt.plot(k,l,"b")
plt.grid()
plt.show()

# %%
x3=fig.add_subplot(2,2,3)
plt.title("3.")
g = tf(1,[3,1,2])
x,y = step_response(g)
plt.plot(x,y,"g")
plt.grid()
plt.show()

# %%
x4=fig.add_subplot(2,2,4)
plt.title("4.")
g = tf(1,[3,5,2])
m,n = step_response(g)
plt.plot(m,n,"k")
plt.grid()
plt.show()

# %%
"""
birinci ve ikinci grafik> s^2nin katsayısın artması (1->3) sistemin overshootunu ve osilasyonunu artırdı.
(s^2 nin katsayının azalmasında tersi durum gerçekleşir.)

>Sistemin kazancı yine bir fakat ikinci grafikte daha uzun zamanda kazanç elde etti.
"""

# %%
"""
ikinci ve üçüncü grafik-> sabit sayının artması (1->2) sistemin kazancını düşürdü,osilasyon arttı.

"""

# %%
"""
üçüncü ve dördüncü grafik-> s'in katsayısının artması (1->5) sistemin kazancını çok değiştirmedi,osilasyon ve overshoot olmadı.

"""

# %%
"""
birinci ve dördüncü grafik-> tüm katsayıların artması sistemin kazancını düşürdü.

"""

# %%
from control import *
import matplotlib.pyplot as plt
# %matplotlib notebook
fig=plt.figure()
ax=fig.add_subplot(1,1,1)

g1 = tf(1,[1,1,1])
a,b = step_response(g1)
plt.plot(a,b,"r")
plt.grid()
plt.xlabel("a")
plt.ylabel("b")


x2=fig.add_subplot(1,1,1)
g2 = tf(1,[3,1,1])
k,l = step_response(g2)
plt.plot(k,l,"b")
plt.grid()
plt.xlabel("k")
plt.ylabel("l")

x3=fig.add_subplot(1,1,1)
g3 = tf(1,[3,1,2])
x,y = step_response(g3)
plt.plot(x,y,"g")
plt.grid()
plt.xlabel("x")
plt.ylabel("y")

x4=fig.add_subplot(1,1,1)
g4 = tf(1,[3,5,2])
m,n = step_response(g4)
plt.plot(m,n,"k")
plt.grid()
plt.xlabel("m")
plt.ylabel("n")

plt.title("Toplu Grafik")
ax.legend(labels = ('bir','iki','uc','dort'))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\anaconda\envs\notebook\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   from ipykernel import kernelapp as app
# C:\anaconda\envs\notebook\lib\site-packages\ipykernel_launcher.py:23: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
# ...

# %%
from control import *
import matplotlib.pyplot as plt
fig=plt.figure()
x1=fig.add_subplot(2,2,1)
plt.title("1.")
g = tf(1,[3,5,7])
a,b = step_response(g)
plt.plot(a,b,)
plt.grid()

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x2=fig.add_subplot(2,2,2)
plt.title("2.")
g = tf(1,[3,5,3])
k,l = step_response(g)
plt.plot(k,l,)
plt.grid()
plt.show()

# %%
x3=fig.add_subplot(2,2,3)
plt.title("3.")
g = tf(1,[-2,2,3])
x,y = step_response(g)
plt.plot(x,y,)
plt.grid()
plt.show()

# %%
x4=fig.add_subplot(2,2,4)
plt.title("4.")
g = tf(1,[1,2,3])
x,y = step_response(g)
plt.plot(x,y,)
plt.grid()
plt.show()

# %%
"""
birinci ve dördüncü grafik-> tüm katsayıların azalması kazancı düşürdü.

"""

# %%
"""
üçüncü grafikteki sistem çalışmaz

"""

# %%
from control import *
from control.pzmap import pzmap
import matplotlib.pyplot as plt
g = tf([2,2],[2,2,5])
print(g.pole())
print(g.zero())
pzmap(g)
plt.grid()
plt.show()
# Out:
# [-0.5+1.5j -0.5-1.5j]
# [-1.]
# <img src="data:image/png;base64,..." width="640">

# %%
from control import *
from control.pzmap import pzmap
import matplotlib.pyplot as plt
g = tf([2,-2],[1,-7,10])
print(g.pole())
print(g.zero())
pzmap(g)
plt.grid()
# Out:
# [5. 2.]
# [1.]
# <img src="data:image/png;base64,..." width="640">

# %%
"""
Sistemin kutuplarının sağ yarı düzlemde olması,kutupların pozitif olması anlamına gelir.Kutuplar pozitifse sistem kararsızdır.


"""

# %%
from control import *
import matplotlib.pyplot as plt
plt.title("1.")
g = tf([2,2],[2,6,4])
nyquist_plot(g), plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, None)

# %%
plt.title("2.")
g = tf([2,2],[1,-7,10])
nyquist_plot(g), plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, None)

# %%
plt.title("3.")
g = tf([2,2],[1,6,8])
nyquist_plot(g), plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, None)

# %%
plt.title("4.")
g = tf([2,2],[1,-6,8])
nyquist_plot(g), plt.grid()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, None)

# %%
"""birinci ve üçüncü sistemler kararlı. """

# %%
""" 
ikinci ve dördüncü sistemler kararsız.

nyquist yanıtında, grafiğin '+' işaretini her zaman çevrelemesi gerekmez.
Çevrelerse karasız bir kutup vardır diyebiliriz.


"""

# %%
from control import *
g = tf([2,2],[1,6,8])
rlocus(g)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([[-4.00000000e+00, -2.00000000e+00],
#         [-4.00000000e+00, -2.00000000e+00],
#         [-4.46338799e+00, -1.86620385e+00],
#         [-4.88747441e+00, -1.77170926e+00],
#         [-5.28937251e+00, -1.69940300e+00],
#         [-5.67691949e+00, -1.64144786e+00],
#         [-6.05441918e+00, -1.59354001e+00],
#         [-6.42450519e+00, -1.55304584e+00],
#         [-6.78891064e+00, -1.51823222e+00],
#         [-7.14883760e+00, -1.48789709e+00],
#         [-7.50515372e+00, -1.46117281e+00],
#         [-7.85850528e+00, -1.43741309e+00],
#         [-8.20938600e+00, -1.41612420e+00],
#         [-8.55818115e+00, -1.39692089e+00],
#         [-8.90519668e+00, -1.37949720e+00],
#         [-9.25067929e+00, -1.36360642e+00],
#         [-9.59483053e+00, -1.34904702e+00],
#         [-9.93781696e+00, -1.33565243e+00],
#         [-1.02797776e+01, -1.32328361e+00],
#         [-1.06208296e+01, -1.31182342e+00],
# ...

# %%
from control import *
g = tf([2,2],[1,-6,8])
rlocus(g)
# Out:
# <img src="data:image/png;base64,..." width="640">
# (array([[ 2.00000000e+00+0.j        ,  4.00000000e+00+0.j        ],
#         [ 2.10396867e+00+0.j        ,  3.83252300e+00+0.j        ],
#         [ 2.23224265e+00+0.j        ,  3.64074070e+00+0.j        ],
#         [ 2.40777170e+00+0.j        ,  3.40170332e+00+0.j        ],
#         [ 2.46663365e+00+0.j        ,  3.32696429e+00+0.j        ],
#         [ 2.53781139e+00+0.j        ,  3.23990947e+00+0.j        ],
#         [ 2.63281970e+00+0.j        ,  3.12902407e+00+0.j        ],
#         [ 2.87298335e+00+0.j        ,  2.87298335e+00+0.j        ],
#         [ 2.86733537e+00-0.20908649j,  2.86733537e+00+0.20908649j],
#         [ 2.86168739e+00-0.29558505j,  2.86168739e+00+0.29558505j],
#         [ 2.85603941e+00-0.36188407j,  2.85603941e+00+0.36188407j],
#         [ 2.85039143e+00-0.41771502j,  2.85039143e+00+0.41771502j],
#         [ 2.82779951e+00-0.58987362j,  2.82779951e+00+0.58987362j],
# ...

# %%
"""
ilk sistem karalı.
ikinci sistem kararsız.Sağ yarı düzlemde kutup var.

"""
